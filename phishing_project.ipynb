# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12,6)

# %%
data = pd.read_csv("Phishing_Legitimate_full.csv")

# %%
float_cols = data.select_dtypes('float64').columns
for c in float_cols:
    data[c] = data[c].astype('float32')
    
int_cols = data.select_dtypes('int64').columns
for c in int_cols:
    data[c] = data[c].astype('int32')
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  49  CLASS_LABEL                         10000 non-null  int32
# dtypes: float32(3), int32(47)
# memory usage: 1.9 MB

# %%
data.rename(columns={'CLASS_LABEL': 'labels'}, inplace=True)

# %%
data.sample(5)
# Out:
#         id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 2732  2733        2               0          4         45        0
# 3264  3265        2               1          3         72        0
# 7277  7278        1               0          5         72        3
# 7281  7282        1               0          2         64        6
# 5094  5095        2               1          0         23        0
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  NumPercent  \
# 2732                  0         0            0              0           0
# 3264                  0         0            0              0           0
# 7277                  0         0            0              0           0
# 7281                  0         0            0              0           0
# 5094                  0         0            0              0           0
#
#       NumQueryComponents  NumAmpersand  NumHash  NumNumericChars  NoHttps  \
# 2732                   0             0        0                0        1
# 3264                   0             0        0               18        1
# 7277                   0             0        0                8        1
# 7281                   0             0        0                0        1
# 5094                   0             0        0                0        0
#
#       RandomString  IpAddress  DomainInSubdomains  DomainInPaths  \
# 2732             0          0                   0              1
# 3264             1          0                   0              0
# 7277             1          0                   0              0
# 7281             1          0                   0              1
# 5094             0          0                   0              0
#
#       HttpsInHostname  HostnameLength  PathLength  QueryLength  \
# 2732                0              15          23            0
# 3264                0              27          38            0
# 7277                0              16          49            0
# 7281                0               8          49            0
# 5094                0              14           1            0
#
#       DoubleSlashInPath  NumSensitiveWords  EmbeddedBrandName  \
# 2732                  0                  0                  0
# 3264                  0                  0                  0
# 7277                  0                  0                  0
# 7281                  0                  0                  0
# 5094                  0                  0                  0
#
#       PctExtHyperlinks  PctExtResourceUrls  ExtFavicon  InsecureForms  \
# 2732          0.000000            0.000000           0              1
# 3264          0.000000            0.785714           0              1
# 7277          0.207547            0.985915           1              1
# 7281          0.193333            0.814815           1              0
# 5094          0.030769            0.851852           1              0
#
#       RelativeFormAction  ExtFormAction  AbnormalFormAction  \
# 2732                   0              0                   0
# 3264                   0              0                   0
# 7277                   1              1                   0
# 7281                   0              0                   0
# 5094                   0              0                   0
#
#       PctNullSelfRedirectHyperlinks  FrequentDomainNameMismatch  \
# 2732                       0.000000                           0
# 3264                       1.000000                           1
# 7277                       0.056604                           0
# 7281                       0.026667                           0
# 5094                       0.092308                           0
#
#       FakeLinkInStatusBar  RightClickDisabled  PopUpWindow  SubmitInfoToEmail  \
# 2732                    0                   0            0                  0
# 3264                    0                   0            0                  0
# 7277                    0                   0            0                  0
# 7281                    0                   0            0                  1
# 5094                    0                   0            0                  0
#
#       IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 2732              0             0                 0                 1
# 3264              1             0                 0                 1
# 7277              1             0                 0                 1
# 7281              0             0                 0                 1
# 5094              1             0                 0                 1
#
#       UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 2732            1                     1                       1
# 3264            0                    -1                       1
# 7277            0                    -1                       0
# 7281            0                    -1                       1
# 5094            1                     0                       1
#
#       ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  labels
# 2732                    1                                   1       1
# 3264                    1                                  -1       1
# 7277                   -1                                   1       0
# 7281                    0                                   1       0
# 5094                   -1                                   1       0

# %%
data.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      0.000000      0.000000
# 50%        0.000000           0.000000      0.000000      0.000000
# 75%        2.000000           0.000000      0.000000      0.000000
# max       55.000000           9.000000      1.000000      1.000000
#
#        NumUnderscore    NumPercent  NumQueryComponents  NumAmpersand  \
# count    10000.00000  10000.000000        10000.000000  10000.000000
# mean         0.32320      0.073800            0.458600      0.277200
# std          1.11466      0.622248            1.344793      1.117356
# min          0.00000      0.000000            0.000000      0.000000
# 25%          0.00000      0.000000            0.000000      0.000000
# 50%          0.00000      0.000000            0.000000      0.000000
# 75%          0.00000      0.000000            0.000000      0.000000
# max         18.00000     19.000000           23.000000     22.000000
#
#             NumHash  NumNumericChars       NoHttps  RandomString  \
# count  10000.000000     10000.000000  10000.000000   10000.00000
# mean       0.002300         5.810300      0.988800       0.52520
# std        0.047906         9.617877      0.105241       0.49939
# min        0.000000         0.000000      0.000000       0.00000
# 25%        0.000000         0.000000      1.000000       0.00000
# 50%        0.000000         2.000000      1.000000       1.00000
# 75%        0.000000         8.000000      1.000000       1.00000
# max        1.000000       111.000000      1.000000       1.00000
#
#           IpAddress  DomainInSubdomains  DomainInPaths  HttpsInHostname  \
# count  10000.000000        10000.000000   10000.000000          10000.0
# mean       0.017200            0.022200       0.428900              0.0
# std        0.130023            0.147341       0.494944              0.0
# min        0.000000            0.000000       0.000000              0.0
# 25%        0.000000            0.000000       0.000000              0.0
# 50%        0.000000            0.000000       0.000000              0.0
# 75%        0.000000            0.000000       1.000000              0.0
# max        1.000000            1.000000       1.000000              0.0
#
#        HostnameLength    PathLength   QueryLength  DoubleSlashInPath  \
# count     10000.00000  10000.000000  10000.000000       10000.000000
# mean         18.82430     35.564900      8.606500           0.000900
# std           8.11654     24.588502     24.313053           0.029988
# min           4.00000      0.000000      0.000000           0.000000
# 25%          14.00000     18.000000      0.000000           0.000000
# 50%          18.00000     30.000000      0.000000           0.000000
# 75%          22.00000     48.000000      0.000000           0.000000
# max         137.00000    161.000000    188.000000           1.000000
#
#        NumSensitiveWords  EmbeddedBrandName  PctExtHyperlinks  \
# count       10000.000000       10000.000000      10000.000000
# mean            0.109300           0.057100          0.241334
# std             0.368737           0.232045          0.342363
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.071429
# 75%             0.000000           0.000000          0.315874
# max             3.000000           1.000000          1.000000
#
#        PctExtResourceUrls    ExtFavicon  InsecureForms  RelativeFormAction  \
# count        10000.000000  10000.000000   10000.000000        10000.000000
# mean             0.392932      0.167200       0.844000            0.248700
# std              0.387295      0.373173       0.362873            0.432281
# min              0.000000      0.000000       0.000000            0.000000
# 25%              0.030303      0.000000       1.000000            0.000000
# 50%              0.247511      0.000000       1.000000            0.000000
# 75%              0.785714      0.000000       1.000000            0.000000
# max              1.000000      1.000000       1.000000            1.000000
#
#        ExtFormAction  AbnormalFormAction  PctNullSelfRedirectHyperlinks  \
# count     10000.0000        10000.000000                   10000.000000
# mean          0.1018            0.057600                       0.136135
# std           0.3024            0.232997                       0.312426
# min           0.0000            0.000000                       0.000000
# 25%           0.0000            0.000000                       0.000000
# 50%           0.0000            0.000000                       0.000000
# 75%           0.0000            0.000000                       0.047619
# max           1.0000            1.000000                       1.000000
#
#        FrequentDomainNameMismatch  FakeLinkInStatusBar  RightClickDisabled  \
# count                10000.000000         10000.000000        10000.000000
# mean                     0.215300             0.005500            0.014000
# std                      0.411051             0.073961            0.117496
# min                      0.000000             0.000000            0.000000
# 25%                      0.000000             0.000000            0.000000
# 50%                      0.000000             0.000000            0.000000
# 75%                      0.000000             0.000000            0.000000
# max                      1.000000             1.000000            1.000000
#
#         PopUpWindow  SubmitInfoToEmail  IframeOrFrame  MissingTitle  \
# count  10000.000000       10000.000000   10000.000000   10000.00000
# mean       0.004900           0.128800       0.339600       0.03220
# std        0.069832           0.334995       0.473597       0.17654
# min        0.000000           0.000000       0.000000       0.00000
# 25%        0.000000           0.000000       0.000000       0.00000
# 50%        0.000000           0.000000       0.000000       0.00000
# 75%        0.000000           0.000000       1.000000       0.00000
# max        1.000000           1.000000       1.000000       1.00000
#
#        ImagesOnlyInForm  SubdomainLevelRT   UrlLengthRT  PctExtResourceUrlsRT  \
# count      10000.000000      10000.000000  10000.000000          10000.000000
# mean           0.030400          0.956600      0.020200              0.353300
# std            0.171694          0.248037      0.820036              0.888908
# min            0.000000         -1.000000     -1.000000             -1.000000
# 25%            0.000000          1.000000     -1.000000             -1.000000
# 50%            0.000000          1.000000      0.000000              1.000000
# 75%            0.000000          1.000000      1.000000              1.000000
# max            1.000000          1.000000      1.000000              1.000000
#
#        AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# count            10000.000000         10000.000000
# mean                 0.793200             0.173400
# std                  0.521019             0.755771
# min                 -1.000000            -1.000000
# 25%                  1.000000             0.000000
# 50%                  1.000000             0.000000
# 75%                  1.000000             1.000000
# max                  1.000000             1.000000
#
#        PctExtNullSelfRedirectHyperlinksRT        labels
# count                        10000.000000  10000.000000
# mean                             0.314100      0.500000
# std                              0.897843      0.500025
# min                             -1.000000      0.000000
# 25%                             -1.000000      0.000000
# 50%                              1.000000      0.500000
# 75%                              1.000000      1.000000
# max                              1.000000      1.000000

# %%
data['labels'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
def corr_heatmap(data, idx_s, idx_e):
    y = data['labels']
    temp = data.iloc[:, idx_s:idx_e]
    if 'id' in temp.columns:
        del temp['id']
    temp['labels'] = y
    sns.heatmap(temp.corr(), annot=True, fmt='.2f')
    plt.show()

# %%
corr_heatmap(data, 0, 10)

# %%
corr_heatmap(data, 10, 20)

# %%
corr_heatmap(data, 20, 30)

# %%
corr_heatmap(data, 30, 40)

# %%
corr_heatmap(data, 40, 50)

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
X = data.drop(['id', 'labels'], axis=1)
y = data['labels']

# %%
discrete_features = X.dtypes == int

# %%
mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
mi_scores = pd.Series(mi_scores, name='MI Scores', index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
# Out:
# PctExtHyperlinks                      4.706339e-01
# PctExtResourceUrls                    2.941998e-01
# PctNullSelfRedirectHyperlinks         2.348483e-01
# PctExtNullSelfRedirectHyperlinksRT    2.123850e-01
# NumNumericChars                       1.326711e-01
# FrequentDomainNameMismatch            1.254908e-01
# ExtMetaScriptLinkRT                   1.175434e-01
# NumDash                               1.140136e-01
# SubmitInfoToEmail                     7.802617e-02
# NumDots                               6.553700e-02
# PathLength                            6.413269e-02
# QueryLength                           5.818557e-02
# PathLevel                             5.543887e-02
# InsecureForms                         5.508096e-02
# UrlLength                             5.263855e-02
# NumSensitiveWords                     4.180522e-02
# NumQueryComponents                    3.361768e-02
# PctExtResourceUrlsRT                  2.831059e-02
# IframeOrFrame                         2.805496e-02
# HostnameLength                        2.564249e-02
# NumAmpersand                          1.962894e-02
# AbnormalExtFormActionR                1.816610e-02
# UrlLengthRT                           1.513853e-02
# NumDashInHostname                     1.502933e-02
# IpAddress                             1.207265e-02
# AbnormalFormAction                    1.118934e-02
# EmbeddedBrandName                     1.066208e-02
# NumUnderscore                         1.037366e-02
# MissingTitle                          7.353661e-03
# DomainInPaths                         7.003483e-03
# SubdomainLevel                        6.392610e-03
# ExtFormAction                         5.613946e-03
# DomainInSubdomains                    5.497419e-03
# TildeSymbol                           5.362924e-03
# SubdomainLevelRT                      4.503644e-03
# NumPercent                            3.790407e-03
# RandomString                          3.643235e-03
# RelativeFormAction                    3.419686e-03
# RightClickDisabled                    3.024050e-03
# PopUpWindow                           2.919366e-03
# NoHttps                               2.854909e-03
# ExtFavicon                            2.398229e-03
# NumHash                               1.596890e-03
# DoubleSlashInPath                     3.101288e-04
# AtSymbol                              2.079892e-04
# FakeLinkInStatusBar                   1.113537e-04
# ImagesOnlyInForm                      6.785265e-07
# HttpsInHostname                       1.776357e-15
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("MI Scores")
    
plt.figure(dpi=100, figsize=(12,12))
plot_mi_scores(mi_scores)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def train_logistic(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    lr = LogisticRegression(max_iter=10000)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_logistic(data, i)
    print("Performance for Logistic Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for Logistic Model with Top 20 features is precision : 0.9264705882352942, recall : 0.9264705882352942, f1 score : 0.9264705882352942, accuracy : 0.925
# Performance for Logistic Model with Top 21 features is precision : 0.9265700483091788, recall : 0.935609756097561, f1 score : 0.9310679611650486, accuracy : 0.929
# Performance for Logistic Model with Top 22 features is precision : 0.9193391642371235, recall : 0.9311023622047244, f1 score : 0.9251833740831296, accuracy : 0.9235
# Performance for Logistic Model with Top 23 features is precision : 0.9220272904483431, recall : 0.9338598223099703, f1 score : 0.9279058361942129, accuracy : 0.9265
# Performance for Logistic Model with Top 24 features is precision : 0.9257086999022482, recall : 0.9348469891411648, f1 score : 0.9302554027504911, accuracy : 0.929
# Performance for Logistic Model with Top 25 features is precision : 0.9217986314760508, recall : 0.943943943943944, f1 score : 0.9327398615232443, accuracy : 0.932
# Performance for Logistic Model with Top 26 features is precision : 0.93812375249501, recall : 0.9334657398212513, f1 score : 0.9357889497262319, accuracy : 0.9355
# Performance for Logistic Model with Top 27 features is precision : 0.9144230769230769, recall : 0.9351032448377581, f1 score : 0.9246475449684006, accuracy : 0.9225
# Performance for Logistic Model with Top 28 features is precision : 0.9295366795366795, recall : 0.9404296875, f1 score : 0.9349514563106796, accuracy : 0.933
# Performance for Logistic Model with Top 29 features is precision : 0.9264278799612778, recall : 0.9336585365853659, f1 score : 0.9300291545189504, accuracy : 0.928
# Performance for Logistic Model with Top 30 features is precision : 0.9221556886227545, recall : 0.9409368635437881, f1 score : 0.9314516129032258, accuracy : 0.932
# Performance for Logistic Model with Top 31 features is precision : 0.9329329329329329, recall : 0.9452332657200812, f1 score : 0.9390428211586902, accuracy : 0.9395
# Performance for Logistic Model with Top 32 features is precision : 0.9389763779527559, recall : 0.9399014778325123, f1 score : 0.9394387001477105, accuracy : 0.9385
# Performance for Logistic Model with Top 33 features is precision : 0.9356435643564357, recall : 0.945, f1 score : 0.9402985074626865, accuracy : 0.94
# Performance for Logistic Model with Top 34 features is precision : 0.9164118246687054, recall : 0.9287190082644629, f1 score : 0.9225243714725501, accuracy : 0.9245
# Performance for Logistic Model with Top 35 features is precision : 0.9313432835820895, recall : 0.9445005045408678, f1 score : 0.937875751503006, accuracy : 0.938
# Performance for Logistic Model with Top 36 features is precision : 0.9366834170854271, recall : 0.9404641775983855, f1 score : 0.9385699899295065, accuracy : 0.939
# Performance for Logistic Model with Top 37 features is precision : 0.916256157635468, recall : 0.9441624365482234, f1 score : 0.9300000000000002, accuracy : 0.93
# Performance for Logistic Model with Top 38 features is precision : 0.9336585365853659, recall : 0.9560439560439561, f1 score : 0.9447186574531097, accuracy : 0.944
# Performance for Logistic Model with Top 39 features is precision : 0.9298245614035088, recall : 0.9405010438413361, f1 score : 0.9351323300467047, accuracy : 0.9375
# Performance for Logistic Model with Top 40 features is precision : 0.934077079107505, recall : 0.941717791411043, f1 score : 0.9378818737270876, accuracy : 0.939
# Performance for Logistic Model with Top 41 features is precision : 0.9211576846307385, recall : 0.943762781186094, f1 score : 0.9323232323232323, accuracy : 0.933
# Performance for Logistic Model with Top 42 features is precision : 0.9258536585365854, recall : 0.9442786069651742, f1 score : 0.9349753694581281, accuracy : 0.934
# Performance for Logistic Model with Top 43 features is precision : 0.9338014042126379, recall : 0.9529170931422722, f1 score : 0.9432624113475178, accuracy : 0.944
# Performance for Logistic Model with Top 44 features is precision : 0.9422135161606269, recall : 0.9431372549019608, f1 score : 0.9426751592356688, accuracy : 0.9415
# Performance for Logistic Model with Top 45 features is precision : 0.9399806389157793, recall : 0.9482421875, f1 score : 0.9440933398152651, accuracy : 0.9425
# Performance for Logistic Model with Top 46 features is precision : 0.9336585365853659, recall : 0.9419291338582677, f1 score : 0.9377756001959824, accuracy : 0.9365
# Performance for Logistic Model with Top 47 features is precision : 0.9471624266144814, recall : 0.952755905511811, f1 score : 0.9499509322865555, accuracy : 0.949
# Performance for Logistic Model with Top 48 features is precision : 0.9384920634920635, recall : 0.9488465396188566, f1 score : 0.943640897755611, accuracy : 0.9435
# Performance for Logistic Model with Top 49 features is precision : 0.9408766564729868, recall : 0.9389623601220752, f1 score : 0.939918533604888, accuracy : 0.941
# Performance for Logistic Model with Top 50 features is precision : 0.9221902017291066, recall : 0.9619238476953907, f1 score : 0.9416380578715057, accuracy : 0.9405

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.926471  0.926471  0.926471    0.9250
# 1                21   0.926570  0.935610  0.931068    0.9290
# 2                22   0.919339  0.931102  0.925183    0.9235
# 3                23   0.922027  0.933860  0.927906    0.9265
# 4                24   0.925709  0.934847  0.930255    0.9290
# 5                25   0.921799  0.943944  0.932740    0.9320
# 6                26   0.938124  0.933466  0.935789    0.9355
# 7                27   0.914423  0.935103  0.924648    0.9225
# 8                28   0.929537  0.940430  0.934951    0.9330
# 9                29   0.926428  0.933659  0.930029    0.9280
# 10               30   0.922156  0.940937  0.931452    0.9320
# 11               31   0.932933  0.945233  0.939043    0.9395
# 12               32   0.938976  0.939901  0.939439    0.9385
# 13               33   0.935644  0.945000  0.940299    0.9400
# 14               34   0.916412  0.928719  0.922524    0.9245
# 15               35   0.931343  0.944501  0.937876    0.9380
# 16               36   0.936683  0.940464  0.938570    0.9390
# 17               37   0.916256  0.944162  0.930000    0.9300
# 18               38   0.933659  0.956044  0.944719    0.9440
# 19               39   0.929825  0.940501  0.935132    0.9375
# 20               40   0.934077  0.941718  0.937882    0.9390
# 21               41   0.921158  0.943763  0.932323    0.9330
# 22               42   0.925854  0.944279  0.934975    0.9340
# 23               43   0.933801  0.952917  0.943262    0.9440
# 24               44   0.942214  0.943137  0.942675    0.9415
# 25               45   0.939981  0.948242  0.944093    0.9425
# 26               46   0.933659  0.941929  0.937776    0.9365
# 27               47   0.947162  0.952756  0.949951    0.9490
# 28               48   0.938492  0.948847  0.943641    0.9435
# 29               49   0.940877  0.938962  0.939919    0.9410
# 30               50   0.922190  0.961924  0.941638    0.9405

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %%
def train_rfc(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    rfc = RandomForestClassifier(n_estimators=500,  max_depth=32, max_features=1.0)
    
    rfc.fit(X_train, y_train)
    
    y_pred = rfc.predict(X_test)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_rfc(data, i)
    print("Performance for RFC Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for RFC Model with Top 20 features is precision : 0.9763374485596708, recall : 0.9783505154639175, f1 score : 0.9773429454170957, accuracy : 0.978
# Performance for RFC Model with Top 21 features is precision : 0.9809236947791165, recall : 0.977, f1 score : 0.9789579158316633, accuracy : 0.979
# Performance for RFC Model with Top 22 features is precision : 0.9736842105263158, recall : 0.9832677165354331, f1 score : 0.9784524975514203, accuracy : 0.978
# Performance for RFC Model with Top 23 features is precision : 0.9708249496981891, recall : 0.9727822580645161, f1 score : 0.9718026183282981, accuracy : 0.972
# Performance for RFC Model with Top 24 features is precision : 0.9762376237623762, recall : 0.985014985014985, f1 score : 0.9806066633515664, accuracy : 0.9805
# Performance for RFC Model with Top 25 features is precision : 0.9822660098522168, recall : 0.9717348927875243, f1 score : 0.9769720725134738, accuracy : 0.9765
# Performance for RFC Model with Top 26 features is precision : 0.9713155291790306, recall : 0.982982982982983, f1 score : 0.9771144278606965, accuracy : 0.977
# Performance for RFC Model with Top 27 features is precision : 0.9765545361875637, recall : 0.9765545361875637, f1 score : 0.9765545361875637, accuracy : 0.977
# Performance for RFC Model with Top 28 features is precision : 0.9729187562688064, recall : 0.9797979797979798, f1 score : 0.9763462506290891, accuracy : 0.9765
# Performance for RFC Model with Top 29 features is precision : 0.9780439121756487, recall : 0.9849246231155779, f1 score : 0.9814722083124687, accuracy : 0.9815
# Performance for RFC Model with Top 30 features is precision : 0.9808429118773946, recall : 0.9817833173537871, f1 score : 0.9813128893148059, accuracy : 0.9805
# Performance for RFC Model with Top 31 features is precision : 0.9771371769383698, recall : 0.9732673267326732, f1 score : 0.9751984126984128, accuracy : 0.975
# Performance for RFC Model with Top 32 features is precision : 0.9690309690309691, recall : 0.980788675429727, f1 score : 0.9748743718592966, accuracy : 0.975
# Performance for RFC Model with Top 33 features is precision : 0.9747729566094854, recall : 0.9807106598984772, f1 score : 0.9777327935222673, accuracy : 0.978
# Performance for RFC Model with Top 34 features is precision : 0.9696356275303644, recall : 0.9775510204081632, f1 score : 0.9735772357723578, accuracy : 0.974
# Performance for RFC Model with Top 35 features is precision : 0.9761194029850746, recall : 0.9684106614017769, f1 score : 0.9722497522299306, accuracy : 0.972
# Performance for RFC Model with Top 36 features is precision : 0.9716312056737588, recall : 0.9677093844601413, f1 score : 0.9696663296258848, accuracy : 0.97
# Performance for RFC Model with Top 37 features is precision : 0.9853862212943633, recall : 0.9742002063983488, f1 score : 0.9797612869745718, accuracy : 0.9805
# Performance for RFC Model with Top 38 features is precision : 0.9646107178968655, recall : 0.9804727646454265, f1 score : 0.9724770642201835, accuracy : 0.973
# Performance for RFC Model with Top 39 features is precision : 0.9764102564102564, recall : 0.9764102564102564, f1 score : 0.9764102564102564, accuracy : 0.977
# Performance for RFC Model with Top 40 features is precision : 0.983201581027668, recall : 0.9783677482792527, f1 score : 0.980778708723509, accuracy : 0.9805
# Performance for RFC Model with Top 41 features is precision : 0.9782608695652174, recall : 0.9782608695652174, f1 score : 0.9782608695652174, accuracy : 0.979
# Performance for RFC Model with Top 42 features is precision : 0.9800399201596807, recall : 0.9790628115653041, f1 score : 0.9795511221945137, accuracy : 0.9795
# Performance for RFC Model with Top 43 features is precision : 0.9726996966632963, recall : 0.983640081799591, f1 score : 0.9781392984239958, accuracy : 0.9785
# Performance for RFC Model with Top 44 features is precision : 0.9781529294935452, recall : 0.9762140733399405, f1 score : 0.9771825396825397, accuracy : 0.977
# Performance for RFC Model with Top 45 features is precision : 0.9835560123329907, recall : 0.9805327868852459, f1 score : 0.9820420728578757, accuracy : 0.9825
# Performance for RFC Model with Top 46 features is precision : 0.9784524975514202, recall : 0.9755859375, f1 score : 0.9770171149144254, accuracy : 0.9765
# Performance for RFC Model with Top 47 features is precision : 0.9835907335907336, recall : 0.9798076923076923, f1 score : 0.9816955684007707, accuracy : 0.981
# Performance for RFC Model with Top 48 features is precision : 0.9803729146221786, recall : 0.9803729146221786, f1 score : 0.9803729146221786, accuracy : 0.98
# Performance for RFC Model with Top 49 features is precision : 0.9808274470232089, recall : 0.9778672032193159, f1 score : 0.979345088161209, accuracy : 0.9795
# Performance for RFC Model with Top 50 features is precision : 0.9752720079129574, recall : 0.9733464955577492, f1 score : 0.9743083003952568, accuracy : 0.974

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %%
top_n_features = mi_scores.sort_values(ascending=False).head(32).index.tolist()
X = data[top_n_features]
y = data['labels']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

rfc = RandomForestClassifier(n_estimators=500, max_depth=32, max_features=1.0)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Performance for RFC Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(27, precision, recall, f1, accuracy))
# Out:
# Performance for RFC Model with Top 27 features is precision : 0.9695481335952849, recall : 0.9733727810650887, f1 score : 0.9714566929133859, accuracy : 0.971

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       986
#            1       0.97      0.97      0.97      1014
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
